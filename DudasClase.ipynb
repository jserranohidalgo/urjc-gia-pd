// %% [markdown]
// # Dudas Ejercicios

// %% [markdown]
// ## 1

// %%
type Not[P] = P => Nothing
// Out:
// defined type Not

// %%
def ej5[P, Q]: Either[P, Q] => Not[P] => Q = 
    (_1: Either[P, Q]) => 
        (_2: P => Nothing) => 
            _1 match {
                case Left(p: P) => _2(p) : Q
                case Right(q: Q) => q : Q 
            }
// Out:
// defined function ej5

// %% [markdown]
// El error lo da en `_2(q)` en la última línea. ¿Por Qué si es Q negada?

// %% [markdown]
// ## 2

// %%
// Ejercicio 3:
def ej3[P, Q]: ((P => Q, P)) => Q = 
    (a: ((P => Q), P)) => 
        a._1(a._2 : P) : Q
// Out:
// defined function ej3

// %%
// Ejercicio 3:
def ej3[P, Q]: (P => Q, P) => Q = 
    (f: P => Q, p: P) => 
        f(p : P) : Q
// Out:
// defined function ej3

// %% [markdown]
// ¿Por qué no puedo nombrar todo lo que quiera?

// %% [markdown]
// # 3

// %%
// Ejercicio 7:
def ej7[P, Q]: (P => Q) => (Not[Q] => Not[P]) = 
    (_1: P => Q) => (nq: Q => Nothing) => (p: P) => 
        nq(_1(p : P) : Q) : Nothing
// Out:
// defined function ej7

// %% [markdown]
// ¿Cómo se hace? No deja definir la siguiente implicación

// %% [markdown]
// # 4

// %%
// Ejercicio 8:
def ej8[P, Q]: Not[(P, Q)] => Either[Not[P], Not[Q]] = 
    {(a : Not[(P, Q)]) => 
        //Left((p: P) => a((p, ???)))
        Right((q: Q) => a((???, q)))
    }
// Out:
// defined function ej8

// %% [markdown]
// ¿Le ponemos los `'{}'` porque estamos definiendo un `Either`?
